# %% [markdown]
# Bold = \033[1m
# Italics = \033[3m
# Underline = \033[4m
# Close = \033[0m

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import pandas as pd
df=pd.read_csv("demand.csv")

# %%
print(df)
# Out:
#       Id  StoreID  TotalPrice  SoldPrice  UnitsSold
# 0      1      993     1050.00      770.0     208500
# 1      2      979      990.00      874.0     181500
# 2      3      979      914.75      841.0     223500
# 3      4      979      958.00      890.0     140000
# 4      5      979      995.00      922.0     250000
# ..   ...      ...         ...        ...        ...
# 145  146     1970      510.10      488.8     130000
# 146  147     1970      505.00      475.0     105000
# 147  148     1970      509.95      388.1     222500
# 148  149     1970      472.00      424.0     141000
# 149  150     2004      480.00      470.0      10000
#
# [150 rows x 5 columns]

# %%
print("\033[1;4mHead of the dataset:\033[0m\n")
print(df.head())
# Out:
# Head of the dataset:
#
#    Id  StoreID  TotalPrice  SoldPrice  UnitsSold
# 0   1      993     1050.00      770.0     208500
# 1   2      979      990.00      874.0     181500
# 2   3      979      914.75      841.0     223500
# 3   4      979      958.00      890.0     140000
# 4   5      979      995.00      922.0     250000

# %%
print("\033[1;4mTail of the dataset:\033[0m\n")
print(df.tail())
# Out:
# Tail of the dataset:
#
#       Id  StoreID  TotalPrice  SoldPrice  UnitsSold
# 145  146     1970      510.10      488.8     130000
# 146  147     1970      505.00      475.0     105000
# 147  148     1970      509.95      388.1     222500
# 148  149     1970      472.00      424.0     141000
# 149  150     2004      480.00      470.0      10000

# %%
print("\033[1;4mShape of the dataset:\033[0m\n")
print(df.shape)
# Out:
# Shape of the dataset:
#
# (150, 5)

# %%
print("\033[1;4mInformation of the dataset\033[0m\n")
print(df.info())
# Out:
# Information of the dataset
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          150 non-null    int64
#  1   StoreID     150 non-null    int64
#  2   TotalPrice  150 non-null    float64
#  3   SoldPrice   150 non-null    float64
#  4   UnitsSold   150 non-null    int64
# dtypes: float64(2), int64(3)
# memory usage: 6.0 KB
# None

# %%
#Finding the Count of the dataset
print("\033[1;4mCount the values:\033[0m\n\n",df.count())
# Out:
# Count the values:
#
#  Id            150
# StoreID       150
# TotalPrice    150
# SoldPrice     150
# UnitsSold     150
# dtype: int64

# %%
#Finding the Missing values in the dataset
print("\033[1;4mmissing values in the dataset:\033[0m\n")
print(df.isnull().sum())
# Out:
# missing values in the dataset:
#
# Id            0
# StoreID       0
# TotalPrice    0
# SoldPrice     0
# UnitsSold     0
# dtype: int64

# %%
#Finding the Duplicated Items of the dataset
d=df[df.duplicated()]
print("\033[1;4mDuplicate entries:\033[0m\n")
print(d)
# Out:
# Duplicate entries:
#
# Empty DataFrame
# Columns: [Id, StoreID, TotalPrice, SoldPrice, UnitsSold]
# Index: []

# %%
#descriptive statistics
print("\033[1;4mMean:\033[0m\n",df.mean())
print("\033[1;4mMedian:\033[0m\n",df.median())
print("\033[1;4mVariance:\033[0m\n",df.var())
print("\033[1;4mStandard deviation:\033[0m\n",df.std())
print("\033[1;4mMaximum value:\033[0m\n",df.max())
print("\033[1;4mMinimum value:\033[0m\n",df.min())
# Out:
# Mean:
#  Id                75.500000
# StoreID         1382.020000
# TotalPrice       819.317667
# SoldPrice        763.651667
# UnitsSold     173052.933333
# dtype: float64
# Median:
#  Id                75.50
# StoreID         1274.00
# TotalPrice       778.35
# SoldPrice        725.25
# UnitsSold     157500.00
# dtype: float64
# Variance:
#  Id            1.887500e+03
# StoreID       9.974626e+04
# TotalPrice    4.814909e+04
# SoldPrice     4.396961e+04
# UnitsSold     4.780338e+09
# dtype: float64
# Standard deviation:
#  Id               43.445368
# StoreID         315.826315
# TotalPrice      219.429014
# SoldPrice       209.689323
# UnitsSold     69139.986318
# dtype: float64
# Maximum value:
#  Id               150.0
# StoreID         2004.0
# TotalPrice      1324.0
# SoldPrice       1270.0
# UnitsSold     438780.0
# dtype: float64
# Minimum value:
#  Id                1.0
# StoreID         979.0
# TotalPrice      472.0
# SoldPrice       388.1
# UnitsSold     10000.0
# dtype: float64

# %%
##Finding the Interquartile range of the dataset
print("\033[1;4mInterquartile:\033[0m\n\n",df.quantile())
# Out:
# Interquartile:
#
#  Id                75.50
# StoreID         1274.00
# TotalPrice       778.35
# SoldPrice        725.25
# UnitsSold     157500.00
# Name: 0.5, dtype: float64

# %%
#Aggregate functions
x=df.aggregate(["sum"])
print(x)
y=df.aggregate(["max"])
print(y)
z=df.aggregate(["mean"])
print(z)
s=df.aggregate(["sem"])
print(s)
p=df.aggregate(["var"])
print(p)
q=df.aggregate(["prod"])
print(q)
# Out:
#         Id  StoreID  TotalPrice  SoldPrice  UnitsSold
# sum  11325   207303   122897.65  114547.75   25957940
#       Id  StoreID  TotalPrice  SoldPrice  UnitsSold
# max  150     2004      1324.0     1270.0     438780
#         Id  StoreID  TotalPrice   SoldPrice      UnitsSold
# mean  75.5  1382.02  819.317667  763.651667  173052.933333
#            Id    StoreID  TotalPrice  SoldPrice    UnitsSold
# sem  3.547299  25.787111   17.916304  17.121062  5645.256243
#          Id       StoreID    TotalPrice     SoldPrice     UnitsSold
# var  1887.5  99746.261342  48149.092152  43969.612296  4.780338e+09
#       Id  StoreID  TotalPrice  SoldPrice  UnitsSold
# prod   0        0         inf        inf          0

# %%
# descriptive statistics for Grouped data
df1=df.groupby(['UnitsSold'])
print(df1.first())
print("Mean=\n",df1['UnitsSold'].mean())
print("Median=\n",df1['UnitsSold'].median())
print("Variance=\n",df1['UnitsSold'].var())
print("Standard deviation=\n",df1['UnitsSold'].std())
print("Maximum value=\n",df1['UnitsSold'].max())
print("Minimum value=\n",df1['UnitsSold'].min())
# Out:
#             Id  StoreID  TotalPrice  SoldPrice
# UnitsSold
# 10000      150     2004      480.00     470.00
# 40000       31     1159     1199.80    1110.00
# 68500       30     1159     1210.00    1151.00
# 80000       69     1512      708.95     642.00
# 82000       40     1159      881.90     760.00
# ...        ...      ...         ...        ...
# 325300      21     1159     1240.00    1204.00
# 345000      12      979     1065.00    1016.00
# 383970     113     1512      827.50     786.15
# 385000      54     1157      734.95     655.60
# 438780      59     1157      786.90     760.20
#
# [126 rows x 4 columns]
# Mean=
#  UnitsSold
# 10000      10000.0
# 40000      40000.0
# 68500      68500.0
# 80000      80000.0
# 82000      82000.0
#             ...
# 325300    325300.0
# 345000    345000.0
# 383970    383970.0
# 385000    385000.0
# 438780    438780.0
# Name: UnitsSold, Length: 126, dtype: float64
# Median=
#  UnitsSold
# 10000      10000.0
# 40000      40000.0
# 68500      68500.0
# 80000      80000.0
# 82000      82000.0
#             ...
# 325300    325300.0
# 345000    345000.0
# 383970    383970.0
# 385000    385000.0
# 438780    438780.0
# Name: UnitsSold, Length: 126, dtype: float64
# Variance=
#  UnitsSold
# 10000    NaN
# 40000    NaN
# 68500    NaN
# 80000    NaN
# 82000    NaN
#           ..
# 325300   NaN
# 345000   NaN
# 383970   NaN
# 385000   NaN
# 438780   NaN
# Name: UnitsSold, Length: 126, dtype: float64
# Standard deviation=
#  UnitsSold
# 10000    NaN
# 40000    NaN
# 68500    NaN
# 80000    NaN
# 82000    NaN
#           ..
# 325300   NaN
# 345000   NaN
# 383970   NaN
# 385000   NaN
# 438780   NaN
# Name: UnitsSold, Length: 126, dtype: float64
# Maximum value=
#  UnitsSold
# 10000      10000
# 40000      40000
# 68500      68500
# 80000      80000
# 82000      82000
#            ...
# 325300    325300
# 345000    345000
# 383970    383970
# 385000    385000
# 438780    438780
# Name: UnitsSold, Length: 126, dtype: int64
# Minimum value=
#  UnitsSold
# 10000      10000
# 40000      40000
# 68500      68500
# 80000      80000
# 82000      82000
#            ...
# 325300    325300
# 345000    345000
# 383970    383970
# 385000    385000
# 438780    438780
# Name: UnitsSold, Length: 126, dtype: int64

# %%
#Skewness
print(df.skew())
# Out:
# Id            0.000000
# StoreID       0.845264
# TotalPrice    0.624957
# SoldPrice     0.698458
# UnitsSold     1.067157
# dtype: float64

# %%
#Kurtosis
print(df.kurtosis())
# Out:
# Id           -1.200000
# StoreID      -0.445045
# TotalPrice   -0.515114
# SoldPrice    -0.284009
# UnitsSold     1.688569
# dtype: float64

# %%
import seaborn as sns
fig=plt.figure()
ax=plt.axes(projection='3d')
x=df['UnitsSold']
y=df['SoldPrice']
z=df['TotalPrice']
ax.plot3D(x,y,z,'Red')
ax.set_title('Product Demand')
plt.show()

# %%
plt.plot(df.UnitsSold,df.SoldPrice)
plt.title("Units sold vs sold price ")
plt.xlabel("Units sold")
plt.ylabel("Sold price")
plt.show()

# %%
sns.pairplot(data=df)
plt.show()

# %%
plt.hist(df.UnitsSold,bins=30)
plt.title("sold")
plt.xlabel("sold")
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(5,3),figsize=(12,12))
plt.show()

# %%
f,ax=plt.subplots(figsize=(10,6))
x=df['UnitsSold']
ax=sns.kdeplot(x,shade=True,color='r')
plt.show()
# Out:
# <ipython-input-22-405439a9bad8>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax=sns.kdeplot(x,shade=True,color='r')

# %%
sns.heatmap(df.corr())
plt.show()

# %% [markdown]
# Linear Regression

# %%
x=df['UnitsSold']
y =df['SoldPrice']

# %%
x.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: UnitsSold, dtype: int64

# %%
y.head()
# Out:
# 0    770.0
# 1    874.0
# 2    841.0
# 3    890.0
# 4    922.0
# Name: SoldPrice, dtype: float64

# %%
x.shape
# Out:
# (150,)

# %%
y.shape
# Out:
# (150,)

# %%
x=x.values.reshape(-1,1)

# %%
x.shape
# Out:
# (150, 1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.6,test_size=0.4,random_state=100)

# %%
print(x.shape)
print(y.shape)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (150, 1)
# (150,)
# (90, 1)
# (60, 1)
# (90,)
# (60,)

# %%
regr = linear_model.LinearRegression()
regr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regr.coef_
# Out:
# array([0.00010784])

# %%
regr.intercept_
# Out:
# 717.250125498721

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train,717.25 +0.00010784 *x_train, 'r')
plt.show()

# %%
y_pred = regr.predict(x_test)

res = (y_test - y_pred)
print(res)
# Out:
# 128    -98.865400
# 11     261.544908
# 118    116.290921
# 15     300.064931
# 123     95.303224
# 135   -129.964369
# 32     294.449372
# 1      137.176827
# 116     37.760048
# 45      60.801705
# 40      77.495398
# 115     34.969950
# 26     501.212978
# 28     445.372975
# 145   -242.469388
# 97     -94.368011
# 62     -36.787823
# 77    -240.945867
# 122    103.083569
# 112     27.492365
# 125     33.687354
# 31     329.643899
# 146   -253.573376
# 29     426.362802
# 69    -105.514234
# 149   -248.328530
# 75    -173.013609
# 20     451.669366
# 73    -141.876211
# 120     92.338588
# 81    -243.553639
# 99     -78.756156
# 119    111.065114
# 12     297.470845
# 16     312.981643
# 51      35.552139
# 46      76.902021
# 89    -160.579209
# 136   -120.671314
# 114     39.765270
# 41      84.416993
# 90    -144.001794
# 102    -27.079261
# 109     14.260183
# 37      61.950281
# 6      299.642847
# 25     516.260359
# 21     442.716911
# 92    -148.882044
# 9      331.124698
# 23     532.441396
# 35     260.427166
# 54     -67.269388
# 131   -163.563203
# 127    -34.382247
# 84    -165.421247
# 111    -17.461412
# 96    -119.277988
# 117    135.834600
# 110     37.986513
# Name: SoldPrice, dtype: float64

# %%
r_squared = r2_score(y_test, y_pred)
r_squared
# Out:
# -0.0817264524165684

# %%
print('Mean squared error: %.2f'% mean_squared_error(y_test, y_pred))
print('Mean Absolute Error: %.2f'% mean_absolute_error(y_test, y_pred))
# Out:
# Mean squared error: 51344.24
# Mean Absolute Error: 177.90

# %% [markdown]
# Multiple regression

# %%
X=df[['UnitsSold','SoldPrice','StoreID']]
Y=df['TotalPrice']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=101)

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(X_train,Y_train)
Y_predict=reg.predict(X_test)
print(Y_predict)
# Out:
# [1104.05174243 1115.89516934  892.2442383   669.57113034  859.76573297
#   883.18641278  703.94535096  703.30271626  514.53969262  949.01481658
#   416.33864915 1097.69787498 1132.50530763  890.78250252  732.8450982
#   632.20720136  649.37055054  669.84836546  854.16019201  623.95406508
#   527.03660752  869.00608553  644.28487393  773.99421111  693.62005273
#   791.58786494  664.48127005  828.76739852 1319.45019795  888.27386428
#   767.87606145  627.88368297  828.43147273  532.18837262  817.63712025
#   747.79167903  664.45937372  790.51677381  660.42981722  638.34994789
#  1245.11552462 1321.89466218 1228.18791895  558.46281738  787.85535163]

# %%
print('Coefficients:',reg.coef_)
# Out:
# Coefficients: [-9.86299297e-05  9.96686153e-01 -4.47452456e-02]

# %%
print('Variance score:{}'.format(reg.score(X_test,Y_test)))
# Out:
# Variance score:0.9816997288894445
